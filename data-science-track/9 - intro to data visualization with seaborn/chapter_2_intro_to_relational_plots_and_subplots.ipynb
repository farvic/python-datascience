# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.relplot(x="total_bill",y="tip",data=tips,kind="scatter",col="smoker",row="time")

plt.show()

# %% [markdown]
# ### Wrapping columns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.relplot(x="total_bill",y="tip",data=tips,
						kind="scatter",col="day",col_wrap=2,
                        col_order=["Thur","Fri","Sat","Sun"])

plt.show()

# %% [markdown]
# ### Exercise

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

student_data = pd.read_csv("student-alcohol-consumption.csv")

# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row="famsup",
            row_order=["yes", "no"])

# Show plot
plt.show()

# %% [markdown]
# ### Subgroups with point size

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.relplot(x="total_bill", y="tip",
						data=tips, kind="scatter", size="size", hue="size")

plt.show()

# %% [markdown]
# ### Subgroups with point style

# %%
import seaborn as sns
import matplotlib.pyplot as plt

palette = sns.color_palette("Set1", 2)
style_order = ["No", "Yes"]

tips = sns.load_dataset("tips")

sns.relplot(x="total_bill", y="tip",
						data=tips, kind="scatter", style="smoker", hue="smoker", style_order=style_order, palette=palette)

plt.show()

# %% [markdown]
# ### Subgroups with point transparency

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set alpha to be between 0 and 1
sns.relplot(x="total_bill",y="tip",data=tips,kind="scatter",alpha=0.4)

plt.show()

# %% [markdown]
# ### SNS Example datasets

# %%
import seaborn as sns

print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ### Lineplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

np.random.seed(42)

hours = np.repeat(np.arange(0,24,1),4)

location = ["East","North","South","West"].copy() * 24

no2_mean = np.random.random_sample(96) * 30 + 10

# dashes parameter can be set to false
sns.relplot(x=hours, y=no2_mean, kind="line", style=location, hue=location, markers=True, height=5, aspect=2)

plt.show()

# %% [markdown]
# ### Line plot with multiple observations per x value

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

mpg = pd.read_csv("mpg.csv")

# Create line plot of model year vs. horsepower
sns.relplot(kind="line", data=mpg, x="model_year", y="horsepower")

# Show plot
plt.show()

# %% [markdown]
# The shaded area is the confidence interval ci.
#
# To disable the confidence interval, set ci=None.

# %%
# Add markers and make each line have the same style
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line",errorbar=None, style="origin", 
            hue="origin", dashes=False, markers=True)

# Show plot
plt.show()
