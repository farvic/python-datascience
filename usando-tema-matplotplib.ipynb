# %%
import matplotlib

matplotlib.get_configdir()
# Out:
# 'C:\\Users\\vicfa\\.matplotlib'

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('rose-pine')

v = np.array([1, 2, 3, 4, 5])

plt.plot(v)
